# %%
import pandas as pd

# %%
from bs4 import BeautifulSoup

# %%
url = "https://www.worldometers.info/coronavirus/#countries"

# %%
import requests

# %%
req = requests.get(url)
soup = BeautifulSoup(req.content, 'html.parser')

# %%
table = soup.find_all(id = "main_table_countries")[0]
table
# Out:
# <table class="table table-bordered table-hover" id="main_table_countries" style="width:100%"> <thead> <tr> <th width="100">Country,<br>Other</br></th> <th width="20">Total<br>Cases</br></th> <!--<th width="20">%&nbsp;of&nbsp;All<br />Cases</th>--> <th width="30">New<br>Cases</br></th> <th width="30">Total<br/>Deaths</th> <th width="30">New<br/>Deaths</th> <th width="30">Total<br/>Recovered</th> <!--<th width="30">New<br />Recovered</th>--> <th width="30">Active<br/>Cases</th> <th width="30">Serious,<br/>Critical</th> <!--<th width="30">Death<br />Rate</th> --> <th width="30">Tot Cases/<br/>1M pop</th> </tr> </thead> <tbody> <tr style=""> <td style="font-weight: bold; font-size:15px; text-align:left;"> <a class="mt_a" href="country/china/">China</a> </td> <td style="font-weight: bold; text-align:right">80,894</td> <!--<td style="font-weight: bold; text-align:right">40.77%</td>--> <td style="font-weight: bold; text-align:right;background-color:#FFEEAA;"> +13 </td> <td style="font-weight: bold; text-align:right;"> 3,237 </td> <td style="font-weight: bold; text-align:right;background-color:red; color:white">+11 </td> <td style="font-weight: bold; text-align:right">69,614 </td> <!-- <td style="font-weight: bold; text-align:right;background-color:green; color:white">+926 </td>--> <td style="text-align:right;font-weight:bold;"> 8,043 </td> <td style="font-weight: bold; text-align:right">2,622 </td> <!-- <td style="font-weight: bold; text-align:right;">4.4% </td>--> <td style="font-weight: bold; text-align:right">56</td> </tr> <tr style=""> <td style="font-weight: bold; font-size:15px; text-align:left;"> <a class="mt_a" href="country/italy/">Italy</a> </td> <td style="font-weight: bold; text-align:right">31,506</td> <!--<td style="font-weight: bold; text-align:right">15.88%</td>--> <td style="font-weight: bold; text-align:right;background-color:#FFEEAA;"> +3,526 </td> <td style="font-weight: bold; text-align:right;"> 2,503 </td> <td style="font-weight: bold; text-align:right;background-color:red; color:white">+345 </td> <td style="font-weight: bold; text-align:right">2,941 </td> <!-- <td style="font-weight: bold; text-align:right;background-color:green; color:white">+192 </td>--> <td style="text-align:right;font-weight:bold;"> 26,062 </td> <td style="font-weight: bold; text-align:right">2,060 </td> <!-- <td style="font-weight: bold; text-align:right;">46.0% </td>--> <td style="font-weight: bold; text-align:right">521</td> </tr> <tr style=""> <td style="font-weight: bold; font-size:15px; text-align:left;"> <a class="mt_a" href="country/iran/">Iran</a> </td> <td style="font-weight: bold; text-align:right">16,169</td> <!--<td style="font-weight: bold; text-align:right">8.15%</td>--> <td style="font-weight: bold; text-align:right;background-color:#FFEEAA;"> +1,178 </td> <td style="font-weight: bold; text-align:right;"> 988 </td> <td style="font-weight: bold; text-align:right;background-color:red; color:white">+135 </td> <td style="font-weight: bold; text-align:right">5,389 </td> <!-- <td style="font-weight: bold; text-align:right;background-color:green; color:white">+393 </td>--> <td style="text-align:right;font-weight:bold;"> 9,792 </td> <td style="font-weight: bold; text-align:right"> </td> <!-- <td style="font-weight: bold; text-align:right;">15.5% </td>--> <td style="font-weight: bold; text-align:right">193</td> </tr> <tr style=""> <td style="font-weight: bold; font-size:15px; text-align:left;"> <a class="mt_a" href="country/spain/">Spain</a> </td> <td style="font-weight: bold; text-align:right">11,826</td> <!--<td style="font-weight: bold; text-align:right">5.96%</td>--> <td style="font-weight: bold; text-align:right;background-color:#FFEEAA;"> +1,884 </td> <td style="font-weight: bold; text-align:right;"> 533 </td> <td style="font-weight: bold; text-align:right;background-color:red; color:white">+191 </td> <td style="font-weight: bold; text-align:right">1,028 </td> <!-- <td style="font-weight: bold; text-align:right;background-color ...

# %%
df = pd.read_html(str(table))

# %%
type(df)
# Out:
# list

# %%
type(table)
# Out:
# bs4.element.Tag
